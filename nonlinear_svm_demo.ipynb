# %% [markdown]
# Activating the cell below animates parameter tuning of a (polynomial) nonlinear svm classifier on the 2-class toy dataset (red class vs. blue class) illustrated in the left panel below.  Newton's method (a nonlinear optimization technique) is used to tune the parameters.  In the
#
# **Left Panel** - the nonlinear boundary produced at each step of the algorithm is shown in black, with the regions of the plane colored according to how the classifier labels all points shown.  Notice how the nonlinear boundary changes and evolves as the algorithm takes subsequent steps, especially during the first few steps, and then how the boundary stabilizes after several steps are taken.
#
# **Right Panel** - the model value (or cost function value) at each step of the algorithm.  Notice how this value tends to goes down at each iteration.
#
# In the function call *animated_nonlinear_2class_demo.run* one can control both the dataset used, as well as the degree of the polynomial.  Try playing around with both!  The higher the degree chosen, the more nonlinear the corresponding boundary will become.
#
# For a given dataset, can you determine a degree that seems to work well?  That is, a value for the degree that appears to produce a boundary that classifies the given points correctly but is not overly flexible, i.e., one that classifies all of the given points correctly but seems to be classifying other regions of the plane incorrectly?

# %%
# %matplotlib inline
import animated_nonlinear_2class_demo
# run the Newton's method algorithm to perform nonlinear classification on a toy dataset
animated_nonlinear_2class_demo.run(dataset = '2linear_data.csv', degree = 1)

# %%
import animated_nonlinear_2class_demo
# run the Newton's method algorithm to perform nonlinear classification on a toy dataset
animated_nonlinear_2class_demo.run(dataset = '2eggs_data.csv', degree = 4)

# %%
import animated_nonlinear_2class_demo
# run the Newton's method algorithm to perform nonlinear classification on a toy dataset
animated_nonlinear_2class_demo.run(dataset = '4eggs_data.csv', degree = 4)
